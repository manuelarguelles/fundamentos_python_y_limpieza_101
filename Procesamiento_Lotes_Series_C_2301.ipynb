# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelarguelles/fundamentos_python_y_limpieza_101/blob/main/Procesamiento_Lotes_Series_C_2301.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Procesamiento de Indicadores Financieros - Cajas Rurales de Ahorro y Crédito
#
# ## Objetivo
# Transformar el archivo Excel de indicadores financieros de formato wide (una columna por CRAC) a formato long (normalizado) con estructura:
# - `periodo`: Fecha del reporte
# - `crac`: Nombre de la caja rural
# - `categoria`: Categoría del indicador (SOLVENCIA, CALIDAD, etc.)
# - `indicador`: Nombre específico del indicador
# - `valor`: Valor numérico
#
# ---

# %%
# Importar librerías
import pandas as pd
import numpy as np
import re
from datetime import datetime

print("✓ Librerías importadas correctamente")
# Out:
# ✓ Librerías importadas correctamente

# %% [markdown]
# ---
# ## 1. Configuración de Ruta y Listado de Archivos
#
# Procesaremos todos los archivos Excel (.xls, .xlsx) en la carpeta especificada.

# %%
import glob
import os

# Configurar la ruta donde están los archivos Excel
# Cambiar esta ruta según tu estructura de carpetas
ruta_archivos = '/content/'  # Ruta por defecto en Colab

# Alternativamente, si montaste Google Drive:
# ruta_archivos = '/content/drive/MyDrive/tu_carpeta/'

# Listar todos los archivos Excel en la ruta
extensiones = ['*.xls', '*.xlsx', '*.XLS', '*.XLSX']
archivos_excel = []

for extension in extensiones:
    archivos_excel.extend(glob.glob(os.path.join(ruta_archivos, extension)))

# Ordenar archivos alfabéticamente
archivos_excel.sort()

print(f"=== ARCHIVOS EXCEL ENCONTRADOS ===")
print(f"Ruta: {ruta_archivos}")
print(f"Total de archivos: {len(archivos_excel)}\n")

if len(archivos_excel) == 0:
    print("⚠️ No se encontraron archivos Excel en la ruta especificada")
    print("Verifica que la ruta sea correcta y contenga archivos .xls o .xlsx")
else:
    print("Archivos a procesar:")
    for i, archivo in enumerate(archivos_excel, 1):
        nombre_archivo = os.path.basename(archivo)
        tamaño = os.path.getsize(archivo) / 1024  # KB
        print(f"  {i}. {nombre_archivo} ({tamaño:.1f} KB)")
# Out:
# === ARCHIVOS EXCEL ENCONTRADOS ===
# Ruta: /content/
# Total de archivos: 19
#
# Archivos a procesar:
#   1. C-2301-ab2024.XLS (48.0 KB)
#   2. C-2301-ab2025.XLS (48.0 KB)
#   3. C-2301-ag2024.XLS (48.0 KB)
#   4. C-2301-di2024.XLS (38.5 KB)
#   5. C-2301-en2024.XLS (47.5 KB)
#   6. C-2301-en2025.XLS (48.0 KB)
#   7. C-2301-fe2024.XLS (48.0 KB)
#   8. C-2301-fe2025.XLS (48.0 KB)
#   9. C-2301-jl2024.XLS (48.0 KB)
#   10. C-2301-jl2025.XLS (47.5 KB)
#   11. C-2301-jn2024.XLS (47.5 KB)
#   12. C-2301-jn2025.XLS (47.0 KB)
#   13. C-2301-ma2024.XLS (47.5 KB)
#   14. C-2301-ma2025.XLS (48.0 KB)
#   15. C-2301-my2024.XLS (48.0 KB)
#   16. C-2301-my2025.XLS (45.5 KB)
#   17. C-2301-no2024.XLS (48.0 KB)
#   18. C-2301-oc2024.XLS (48.0 KB)
#   19. C-2301-se2024.XLS (48.0 KB)

# %% [markdown]
# ---
# ## 2. Función de Procesamiento de Archivo Individual
#
# Creamos una función que procesa un archivo Excel y retorna el DataFrame normalizado.

# %%
def procesar_archivo_crac(ruta_archivo):
    """
    Procesa un archivo Excel de indicadores CRAC y retorna DataFrame normalizado

    Parámetros:
    -----------
    ruta_archivo : str
        Ruta completa al archivo Excel

    Retorna:
    --------
    pd.DataFrame : DataFrame normalizado con columnas [periodo, crac, categoria, indicador, valor]
    """

    nombre_archivo = os.path.basename(ruta_archivo)
    print(f"\n{'='*60}")
    print(f"Procesando: {nombre_archivo}")
    print('='*60)

    try:
        # 1. Leer archivo completo para extraer período
        df_raw = pd.read_excel(ruta_archivo, header=None)

        # 2. Extraer período de la celda A3 (índice 2)
        periodo_texto = df_raw.iloc[2, 0]
        print(f"Período extraído: {periodo_texto}")
        print(f"Tipo: {type(periodo_texto)}")

        # Función para parsear fecha (maneja datetime y string)
        def extraer_periodo(texto):
            # Caso 1: Ya es un objeto datetime
            if isinstance(texto, datetime):
                print("  → Ya es datetime, usando directamente")
                return texto

            # Caso 2: Es pd.Timestamp
            if isinstance(texto, pd.Timestamp):
                print("  → Es pd.Timestamp, convirtiendo a datetime")
                return texto.to_pydatetime()

            # Caso 3: Es string, parsear
            if isinstance(texto, str):
                print("  → Es string, parseando...")
                meses = {
                    'enero': 1, 'febrero': 2, 'marzo': 3, 'abril': 4,
                    'mayo': 5, 'junio': 6, 'julio': 7, 'agosto': 8,
                    'septiembre': 9, 'octubre': 10, 'noviembre': 11, 'diciembre': 12
                }
                patron = r'(\d+)\s+de\s+(\w+)\s+de\s+(\d{4})'
                match = re.search(patron, texto.lower())

                if match:
                    dia = int(match.group(1))
                    mes_texto = match.group(2)
                    año = int(match.group(3))
                    mes = meses.get(mes_texto, 1)
                    return datetime(año, mes, dia)

            # Si no se pudo extraer, intentar conversión directa
            try:
                return pd.to_datetime(texto)
            except:
                return None

        periodo = extraer_periodo(periodo_texto)

        if periodo is None:
            print(f"⚠️ No se pudo extraer el período del archivo")
            return None

        print(f"  → Período final: {periodo.strftime('%Y-%m-%d')}")

        # 3. Leer con headers correctos (fila 5, índice 4)
        df = pd.read_excel(ruta_archivo, header=4)

        # Limpiar nombres de columnas (eliminar saltos de línea y espacios extras)
        df.columns = df.columns.map(lambda x: str(x).replace('\n', ' ').replace('\r', ' ').strip())
        df.columns = df.columns.map(lambda x: ' '.join(x.split()))  # Eliminar espacios múltiples

        print(f"  → Columnas después de limpieza:")
        for col in df.columns:
            print(f"     • {col}")

        # 4. Buscar fila de "Nota" y filtrar
        fila_nota = None
        for idx, row in df.iterrows():
            if pd.notna(row.iloc[0]) and 'Nota' in str(row.iloc[0]):
                fila_nota = idx
                break

        if fila_nota is not None:
            df = df.iloc[:fila_nota].copy()
            print(f"  → Datos hasta fila {fila_nota} (antes de notas)")

        # 5. Renombrar primera columna
        df.columns.values[0] = 'indicador'

        # 6. Identificar columnas de CRACs (excluyendo las que empiezan con "Unnamed")
        columnas_cracs = [col for col in df.columns if col != 'indicador' and not col.startswith('Unnamed')]
        print(f"  → CRACs válidas encontradas: {len(columnas_cracs)}")

        # *** NUEVO: Eliminar columnas Unnamed antes del procesamiento ***
        columnas_a_mantener = ['indicador'] + columnas_cracs
        df = df[columnas_a_mantener].copy()

        # Actualizar lista de columnas CRACs después de filtrar
        columnas_cracs = [col for col in df.columns if col != 'indicador']

        # 7. Identificar y marcar categorías
        def es_categoria(row):
            tiene_texto = pd.notna(row['indicador']) and str(row['indicador']).strip() != ''
            valores_vacios = all(pd.isna(row[col]) or str(row[col]).strip() == ''
                               for col in columnas_cracs)
            return tiene_texto and valores_vacios

        df['es_categoria'] = df.apply(es_categoria, axis=1)
        categorias_encontradas = df[df['es_categoria']]['indicador'].tolist()
        print(f"  → Categorías encontradas: {len(categorias_encontradas)}")

        # 8. Asignar categorías (forward fill)
        df['categoria'] = None
        categoria_actual = None
        for idx, row in df.iterrows():
            if row['es_categoria']:
                categoria_actual = row['indicador']
            df.at[idx, 'categoria'] = categoria_actual

        # 9. Eliminar filas de categorías y vacías
        registros_antes = len(df)
        df = df[~df['es_categoria']].copy()
        df = df[pd.notna(df['indicador'])].copy()
        df = df[df['indicador'].astype(str).str.strip() != ''].copy()
        df = df.drop('es_categoria', axis=1)
        print(f"  → Registros de indicadores: {len(df)} (eliminados {registros_antes - len(df)} de categorías/vacíos)")

        # 10. Limpiar nombres (categorías e indicadores)
        df['categoria'] = df['categoria'].str.replace('*', '', regex=False).str.strip()
        df['indicador'] = df['indicador'].str.strip()

        # Limpiar saltos de línea en indicadores
        df['indicador'] = df['indicador'].str.replace('\n', ' ', regex=False)
        df['indicador'] = df['indicador'].str.replace('\r', ' ', regex=False)
        df['indicador'] = df['indicador'].str.replace(r'\s+', ' ', regex=True)  # Espacios múltiples

        # 11. Pivotear a formato long
        df_long = df.melt(
            id_vars=['categoria', 'indicador'],
            var_name='crac',
            value_name='valor'
        )
        print(f"  → Después de pivoteo: {len(df_long)} registros")

        # 12. Limpiar valores numéricos
        def limpiar_valor(valor):
            if isinstance(valor, (int, float)):
                return float(valor)
            if pd.isna(valor):
                return np.nan

            valor_str = str(valor).strip()

            if valor_str == '-':
                return 0.0

            if '(' in valor_str:
                valor_str = valor_str.replace('(', '').replace(')', '').strip()
                try:
                    return -float(valor_str)
                except:
                    return np.nan

            try:
                valor_str = valor_str.replace(' ', '').replace(',', '')
                return float(valor_str)
            except:
                return np.nan

        df_long['valor'] = df_long['valor'].apply(limpiar_valor)

        # 13. Agregar columna de período
        df_long['periodo'] = periodo

        # 14. Reordenar columnas
        df_final = df_long[['periodo', 'crac', 'categoria', 'indicador', 'valor']].copy()
        df_final = df_final.sort_values(['categoria', 'indicador', 'crac']).reset_index(drop=True)

        print(f"✓ Procesado exitosamente: {len(df_final)} registros")
        print(f"  - Categorías: {df_final['categoria'].nunique()}")
        print(f"  - Indicadores: {df_final['indicador'].nunique()}")
        print(f"  - CRACs: {df_final['crac'].nunique()}")

        return df_final

    except Exception as e:
        print(f"✗ Error procesando archivo: {str(e)}")
        import traceback
        print(traceback.format_exc())
        return None

print("✓ Función de procesamiento creada (sin columnas Unnamed)")
# Out:
# ✓ Función de procesamiento creada (sin columnas Unnamed)

# %% [markdown]
# ---
# ## 3. Procesamiento de Todos los Archivos
#
# Iteramos sobre todos los archivos encontrados y consolidamos los resultados.

# %%
# Procesar todos los archivos
dataframes_procesados = []
archivos_exitosos = []
archivos_fallidos = []

for archivo in archivos_excel:
    df_resultado = procesar_archivo_crac(archivo)

    if df_resultado is not None:
        dataframes_procesados.append(df_resultado)
        archivos_exitosos.append(os.path.basename(archivo))
    else:
        archivos_fallidos.append(os.path.basename(archivo))

print(f"\n{'='*60}")
print("RESUMEN DE PROCESAMIENTO")
print('='*60)
print(f"Total archivos procesados: {len(archivos_excel)}")
print(f"Exitosos: {len(archivos_exitosos)}")
print(f"Fallidos: {len(archivos_fallidos)}")

if archivos_fallidos:
    print(f"\n⚠️ Archivos con errores:")
    for archivo in archivos_fallidos:
        print(f"  - {archivo}")
# Out:
# ============================================================
# Procesando: C-2301-ab2024.XLS
# ============================================================
# Período extraído: 2024-04-30 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2024-04-30
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-ab2025.XLS
# ============================================================
# Período extraído: 2025-04-30 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2025-04-30
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-ag2024.XLS
# ============================================================
# Período extraído: 2024-08-31 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2024-08-31
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-di2024.XLS
# ============================================================
# Período extraído: 2024-12-31 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2024-12-31
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-en2024.XLS
# ============================================================
# Período extraído: 2024-01-31 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2024-01-31
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-en2025.XLS
# ============================================================
# Período extraído: 2025-01-31 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2025-01-31
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-fe2024.XLS
# ============================================================
# Período extraído: 2024-02-29 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2024-02-29
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-fe2025.XLS
# ============================================================
# Período extraído: 2025-02-28 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2025-02-28
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-jl2024.XLS
# ============================================================
# Período extraído: 2024-07-31 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2024-07-31
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-jl2025.XLS
# ============================================================
# Período extraído: 2025-07-31 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2025-07-31
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-jn2024.XLS
# ============================================================
# Período extraído: nan
# Tipo: <class 'float'>
# ✗ Error procesando archivo: NaTType does not support strftime
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2397538057.py", line 71, in procesar_archivo_crac
#     print(f"  → Período final: {periodo.strftime('%Y-%m-%d')}")
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "nattype.pyx", line 54, in pandas._libs.tslibs.nattype._make_error_func.f
# ValueError: NaTType does not support strftime
#
#
# ============================================================
# Procesando: C-2301-jn2025.XLS
# ============================================================
# Período extraído: nan
# Tipo: <class 'float'>
# ✗ Error procesando archivo: NaTType does not support strftime
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2397538057.py", line 71, in procesar_archivo_crac
#     print(f"  → Período final: {periodo.strftime('%Y-%m-%d')}")
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "nattype.pyx", line 54, in pandas._libs.tslibs.nattype._make_error_func.f
# ValueError: NaTType does not support strftime
#
#
# ============================================================
# Procesando: C-2301-ma2024.XLS
# ============================================================
# Período extraído: 2024-03-31 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2024-03-31
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-ma2025.XLS
# ============================================================
# Período extraído: 2025-03-31 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2025-03-31
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-my2024.XLS
# ============================================================
# Período extraído: 2024-05-31 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2024-05-31
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-my2025.XLS
# ============================================================
# Período extraído: Actualizado al 21/07/2025
# Tipo: <class 'str'>
#   → Es string, parseando...
# ⚠️ No se pudo extraer el período del archivo
#
# ============================================================
# Procesando: C-2301-no2024.XLS
# ============================================================
# Período extraído: 2024-11-30 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2024-11-30
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-oc2024.XLS
# ============================================================
# Período extraído: 2024-10-31 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2024-10-31
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# Procesando: C-2301-se2024.XLS
# ============================================================
# Período extraído: 2024-09-30 00:00:00
# Tipo: <class 'datetime.datetime'>
#   → Ya es datetime, usando directamente
#   → Período final: 2024-09-30
#   → Columnas después de limpieza:
#      • Unnamed: 0
#      • CRAC Cencosud Scotia
#      • Unnamed: 2
#      • CRAC Los Andes
#      • CRAC Prymera
#      • Unnamed: 5
#      • Unnamed: 6
#      • Unnamed: 7
#      • Unnamed: 8
#      • Unnamed: 9
#      • CRAC Incasur
#      • CRAC del Centro
#      • TOTAL CRAC
#   → Datos hasta fila 32 (antes de notas)
#   → CRACs válidas encontradas: 6
#   → Categorías encontradas: 6
#   → Registros de indicadores: 20 (eliminados 12 de categorías/vacíos)
#   → Después de pivoteo: 120 registros
# ✓ Procesado exitosamente: 120 registros
#   - Categorías: 6
#   - Indicadores: 20
#   - CRACs: 6
#
# ============================================================
# RESUMEN DE PROCESAMIENTO
# ============================================================
# Total archivos procesados: 19
# Exitosos: 16
# Fallidos: 3
#
# ⚠️ Archivos con errores:
#   - C-2301-jn2024.XLS
#   - C-2301-jn2025.XLS
#   - C-2301-my2025.XLS

# %%
# Consolidar todos los DataFrames en uno solo
if len(dataframes_procesados) > 0:
    df_consolidado = pd.concat(dataframes_procesados, ignore_index=True)

    print(f"\n=== DATASET CONSOLIDADO ===")
    print(f"Total de registros: {len(df_consolidado):,}")
    print(f"Períodos únicos: {df_consolidado['periodo'].nunique()}")
    print(f"CRACs únicos: {df_consolidado['crac'].nunique()}")
    print(f"Categorías: {df_consolidado['categoria'].nunique()}")
    print(f"Indicadores únicos: {df_consolidado['indicador'].nunique()}")

    print(f"\n--- Períodos en el dataset ---")
    for periodo in sorted(df_consolidado['periodo'].unique()):
        registros = len(df_consolidado[df_consolidado['periodo'] == periodo])
        print(f"  • {periodo.strftime('%Y-%m-%d')}: {registros:,} registros")

    print(f"\n--- CRACs en el dataset ---")
    for crac in df_consolidado['crac'].unique():
        registros = len(df_consolidado[df_consolidado['crac'] == crac])
        print(f"  • {crac}: {registros:,} registros")

else:
    print("⚠️ No se procesó ningún archivo exitosamente")
    df_consolidado = None
# Out:
# === DATASET CONSOLIDADO ===
# Total de registros: 1,920
# Períodos únicos: 16
# CRACs únicos: 6
# Categorías: 6
# Indicadores únicos: 20
#
# --- Períodos en el dataset ---
#   • 2024-01-31: 120 registros
#   • 2024-02-29: 120 registros
#   • 2024-03-31: 120 registros
#   • 2024-04-30: 120 registros
#   • 2024-05-31: 120 registros
#   • 2024-07-31: 120 registros
#   • 2024-08-31: 120 registros
#   • 2024-09-30: 120 registros
#   • 2024-10-31: 120 registros
#   • 2024-11-30: 120 registros
#   • 2024-12-31: 120 registros
#   • 2025-01-31: 120 registros
#   • 2025-02-28: 120 registros
#   • 2025-03-31: 120 registros
#   • 2025-04-30: 120 registros
#   • 2025-07-31: 120 registros
#
# --- CRACs en el dataset ---
#   • CRAC Cencosud Scotia: 320 registros
#   • CRAC Incasur: 320 registros
#   • CRAC Los Andes: 320 registros
#   • CRAC Prymera: 320 registros
#   • CRAC del Centro: 320 registros
#   • TOTAL CRAC: 320 registros

# %%
# Vista previa del dataset consolidado
if df_consolidado is not None:
    print("Primeras 30 filas del dataset consolidado:")
    print(df_consolidado.head(30))

    print("\n\nÚltimas 30 filas:")
    print(df_consolidado.tail(30))
# Out:
# Primeras 30 filas del dataset consolidado:
#       periodo                  crac           categoria  \
# 0  2024-04-30  CRAC Cencosud Scotia  CALIDAD DE ACTIVOS
# 1  2024-04-30          CRAC Incasur  CALIDAD DE ACTIVOS
# 2  2024-04-30        CRAC Los Andes  CALIDAD DE ACTIVOS
# 3  2024-04-30          CRAC Prymera  CALIDAD DE ACTIVOS
# 4  2024-04-30       CRAC del Centro  CALIDAD DE ACTIVOS
# 5  2024-04-30            TOTAL CRAC  CALIDAD DE ACTIVOS
# 6  2024-04-30  CRAC Cencosud Scotia  CALIDAD DE ACTIVOS
# 7  2024-04-30          CRAC Incasur  CALIDAD DE ACTIVOS
# 8  2024-04-30        CRAC Los Andes  CALIDAD DE ACTIVOS
# 9  2024-04-30          CRAC Prymera  CALIDAD DE ACTIVOS
# 10 2024-04-30       CRAC del Centro  CALIDAD DE ACTIVOS
# 11 2024-04-30            TOTAL CRAC  CALIDAD DE ACTIVOS
# 12 2024-04-30  CRAC Cencosud Scotia  CALIDAD DE ACTIVOS
# 13 2024-04-30          CRAC Incasur  CALIDAD DE ACTIVOS
# 14 2024-04-30        CRAC Los Andes  CALIDAD DE ACTIVOS
# 15 2024-04-30          CRAC Prymera  CALIDAD DE ACTIVOS
# 16 2024-04-30       CRAC del Centro  CALIDAD DE ACTIVOS
# 17 2024-04-30            TOTAL CRAC  CALIDAD DE ACTIVOS
# 18 2024-04-30  CRAC Cencosud Scotia  CALIDAD DE ACTIVOS
# 19 2024-04-30          CRAC Incasur  CALIDAD DE ACTIVOS
# 20 2024-04-30        CRAC Los Andes  CALIDAD DE ACTIVOS
# 21 2024-04-30          CRAC Prymera  CALIDAD DE ACTIVOS
# 22 2024-04-30       CRAC del Centro  CALIDAD DE ACTIVOS
# 23 2024-04-30            TOTAL CRAC  CALIDAD DE ACTIVOS
# 24 2024-04-30  CRAC Cencosud Scotia  CALIDAD DE ACTIVOS
# 25 2024-04-30          CRAC Incasur  CALIDAD DE ACTIVOS
# 26 2024-04-30        CRAC Los Andes  CALIDAD DE ACTIVOS
# 27 2024-04-30          CRAC Prymera  CALIDAD DE ACTIVOS
# 28 2024-04-30       CRAC del Centro  CALIDAD DE ACTIVOS
# 29 2024-04-30            TOTAL CRAC  CALIDAD DE ACTIVOS
#
#                                             indicador       valor
# 0      Cartera de Alto Riesgo / Créditos Directos (%)    8.300000
# 1      Cartera de Alto Riesgo / Créditos Directos (%)   13.570000
# 2      Cartera de Alto Riesgo / Créditos Directos (%)   13.090000
# 3      Cartera de Alto Riesgo / Créditos Directos (%)   10.640000
# 4      Cartera de Alto Riesgo / Créditos Directos (%)    9.090000
# 5      Cartera de Alto Riesgo / Créditos Directos (%)   10.770000
# 6   Créditos Atrasados (criterio SBS)** / Créditos...    4.570000
# 7   Créditos Atrasados (criterio SBS)** / Créditos...   11.320000
# 8   Créditos Atrasados (criterio SBS)** / Créditos...   10.800000
# 9   Créditos Atrasados (criterio SBS)** / Créditos...    7.700000
# 10  Créditos Atrasados (criterio SBS)** / Créditos...    7.640000
# 11  Créditos Atrasados (criterio SBS)** / Créditos...    7.970000
# 12  Créditos Atrasados ME (criterio SBS)** / Crédi...    0.000000
# 13  Créditos Atrasados ME (criterio SBS)** / Crédi...    0.000000
# 14  Créditos Atrasados ME (criterio SBS)** / Crédi...  100.000000
# 15  Créditos Atrasados ME (criterio SBS)** / Crédi...   12.470000
# 16  Créditos Atrasados ME (criterio SBS)** / Crédi...    0.000000
# 17  Créditos Atrasados ME (criterio SBS)** / Crédi...   48.140000
# 18  Créditos Atrasados MN (criterio SBS)** / Crédi...    4.570000
# 19  Créditos Atrasados MN (criterio SBS)** / Crédi...   11.320000
# 20  Créditos Atrasados MN (criterio SBS)** / Crédi...   10.790000
# 21  Créditos Atrasados MN (criterio SBS)** / Crédi...    7.700000
# 22  Créditos Atrasados MN (criterio SBS)** / Crédi...    7.640000
# 23  Créditos Atrasados MN (criterio SBS)** / Crédi...    7.960000
# 24  Créditos Atrasados con más de 90 días de atras...    3.909234
# 25  Créditos Atrasados con más de 90 días de atras...    9.580544
# 26  Créditos Atrasados con más de 90 días de atras...    7.169594
# 27  Créditos Atrasados con más de 90 días de atras...    6.102666
# 28  Créditos Atrasados con más de 90 días de atras...    6.051642
# 29  Créditos Atrasados con más de 90 días de atras...    5.839461
#
#
# Últimas 30 filas:
#         periodo                  crac                      categoria  \
# 1890 2024-09-30  CRAC Cencosud Scotia  POSICIÓN EN MONEDA EXTRANJERA
# 1891 2024-09-30          CRAC Incasur  POSICIÓN EN MONEDA EXTRANJERA
# 1892 2024-09-30        CRAC Los Andes  POSICIÓN EN MONEDA EXTRANJERA
# 1893 2024-09-30          CRAC Prymera  POSICIÓN EN MONEDA EXTRANJERA
# 1894 2024-09-30       CRAC del Centro  POSICIÓN EN MONEDA EXTRANJERA
# 1895 2024-09-30            TOTAL CRAC  POSICIÓN EN MONEDA EXTRANJERA
# 1896 2024-09-30  CRAC Cencosud Scotia                   RENTABILIDAD
# 1897 2024-09-30          CRAC Incasur                   RENTABILIDAD
# 1898 2024-09-30        CRAC Los Andes                   RENTABILIDAD
# 1899 2024-09-30          CRAC Prymera                   RENTABILIDAD
# 1900 2024-09-30       CRAC del Centro                   RENTABILIDAD
# 1901 2024-09-30            TOTAL CRAC                   RENTABILIDAD
# 1902 2024-09-30  CRAC Cencosud Scotia                   RENTABILIDAD
# 1903 2024-09-30          CRAC Incasur                   RENTABILIDAD
# 1904 2024-09-30        CRAC Los Andes                   RENTABILIDAD
# 1905 2024-09-30          CRAC Prymera                   RENTABILIDAD
# 1906 2024-09-30       CRAC del Centro                   RENTABILIDAD
# 1907 2024-09-30            TOTAL CRAC                   RENTABILIDAD
# 1908 2024-09-30  CRAC Cencosud Scotia                      SOLVENCIA
# 1909 2024-09-30          CRAC Incasur                      SOLVENCIA
# 1910 2024-09-30        CRAC Los Andes                      SOLVENCIA
# 1911 2024-09-30          CRAC Prymera                      SOLVENCIA
# 1912 2024-09-30       CRAC del Centro                      SOLVENCIA
# 1913 2024-09-30            TOTAL CRAC                      SOLVENCIA
# 1914 2024-09-30  CRAC Cencosud Scotia                      SOLVENCIA
# 1915 2024-09-30          CRAC Incasur                      SOLVENCIA
# 1916 2024-09-30        CRAC Los Andes                      SOLVENCIA
# 1917 2024-09-30          CRAC Prymera                      SOLVENCIA
# 1918 2024-09-30       CRAC del Centro                      SOLVENCIA
# 1919 2024-09-30            TOTAL CRAC                      SOLVENCIA
#
#                                               indicador      valor
# 1890  Posición Global en M.E. / Patrimonio Efectivo ...  -0.815805
# 1891  Posición Global en M.E. / Patrimonio Efectivo ...   0.673626
# 1892  Posición Global en M.E. / Patrimonio Efectivo ...   2.766624
# 1893  Posición Global en M.E. / Patrimonio Efectivo ...   2.317832
# 1894  Posición Global en M.E. / Patrimonio Efectivo ...  -0.033674
# 1895  Posición Global en M.E. / Patrimonio Efectivo ...   0.875885
# 1896  Utilidad Neta Anualizada sobre Activo Promedio...  -1.541455
# 1897  Utilidad Neta Anualizada sobre Activo Promedio...  -1.356739
# 1898  Utilidad Neta Anualizada sobre Activo Promedio...  -0.419319
# 1899  Utilidad Neta Anualizada sobre Activo Promedio...  -3.592277
# 1900  Utilidad Neta Anualizada sobre Activo Promedio...  -5.685762
# 1901  Utilidad Neta Anualizada sobre Activo Promedio...  -1.693073
# 1902  Utilidad Neta Anualizada sobre Patrimonio Prom...  -6.827787
# 1903  Utilidad Neta Anualizada sobre Patrimonio Prom...  -9.789488
# 1904  Utilidad Neta Anualizada sobre Patrimonio Prom...  -3.411459
# 1905  Utilidad Neta Anualizada sobre Patrimonio Prom... -19.341299
# 1906  Utilidad Neta Anualizada sobre Patrimonio Prom... -83.833785
# 1907  Utilidad Neta Anualizada sobre Patrimonio Prom... -10.257777
# 1908  Pasivo Total / Capital Social y Reservas ( Nº ...   2.360000
# 1909  Pasivo Total / Capital Social y Reservas ( Nº ...   2.540000
# 1910  Pasivo Total / Capital Social y Reservas ( Nº ...   7.700000
# 1911  Pasivo Total / Capital Social y Reservas ( Nº ...   2.070000
# 1912  Pasivo Total / Capital Social y Reservas ( Nº ...   6.220000
# 1913  Pasivo Total / Capital Social y Reservas ( Nº ...   3.520000
# 1914                            Ratio de Capital Global  14.990000
# 1915                            Ratio de Capital Global   9.890000
# 1916                            Ratio de Capital Global  14.710000
# 1917                            Ratio de Capital Global   9.830000
# 1918                            Ratio de Capital Global  12.640000
# 1919                            Ratio de Capital Global  14.081132

# %% [markdown]
# ---
# ## 4. Validaciones de Integridad
#
# Validamos que la columna TOTAL CRAC sea la suma de las demás CRACs para cada período.

# %%
# Validación de integridad por período
if df_consolidado is not None:

    for periodo_val in sorted(df_consolidado['periodo'].unique()):

        print(f"\n{'='*60}")
        print(f"VALIDACIÓN PARA PERÍODO: {periodo_val.strftime('%Y-%m-%d')}")
        print('='*60)

        df_periodo = df_consolidado[df_consolidado['periodo'] == periodo_val]

        # Identificar CRACs
        cracs_individuales = [c for c in df_periodo['crac'].unique() if 'TOTAL' not in c.upper()]
        crac_total_list = [c for c in df_periodo['crac'].unique() if 'TOTAL' in c.upper()]

        if not crac_total_list:
            print("⚠️ No se encontró columna TOTAL CRAC en este período")
            continue

        crac_total = crac_total_list[0]

        validaciones = []

        for categoria in df_periodo['categoria'].unique():
            for indicador in df_periodo[df_periodo['categoria'] == categoria]['indicador'].unique():

                valores_individuales = df_periodo[
                    (df_periodo['categoria'] == categoria) &
                    (df_periodo['indicador'] == indicador) &
                    (df_periodo['crac'].isin(cracs_individuales))
                ]['valor']

                valor_total = df_periodo[
                    (df_periodo['categoria'] == categoria) &
                    (df_periodo['indicador'] == indicador) &
                    (df_periodo['crac'] == crac_total)
                ]['valor'].values

                if len(valor_total) > 0:
                    suma_calculada = valores_individuales.sum()
                    total_reportado = valor_total[0]

                    if not np.isnan(suma_calculada) and not np.isnan(total_reportado):
                        diferencia = abs(suma_calculada - total_reportado)
                        es_valido = diferencia < 0.1

                        validaciones.append({
                            'categoria': categoria,
                            'indicador': indicador,
                            'suma_calculada': round(suma_calculada, 2),
                            'total_reportado': round(total_reportado, 2),
                            'diferencia': round(diferencia, 2),
                            'valido': es_valido
                        })

        df_val = pd.DataFrame(validaciones)

        if len(df_val) > 0:
            print(f"Validaciones realizadas: {len(df_val)}")
            print(f"Exitosas: {df_val['valido'].sum()}")
            print(f"Fallidas: {(~df_val['valido']).sum()}")

            if (~df_val['valido']).any():
                print("\n⚠️ Validaciones fallidas:")
                print(df_val[~df_val['valido']][['categoria', 'indicador', 'diferencia']])
            else:
                print("✓ Todas las validaciones pasaron")
# Out:
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2024-01-31
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       43.15
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       34.44
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       66.88
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       34.42
# 4   Créditos Atrasados con más de 90 días de atras...       23.88
# 5                Provisiones / Créditos Atrasados (%)      549.62
# 6            Créditos Directos / Empleados (Miles S/)     3366.27
# 7   Créditos Directos / Número de Oficinas (Miles S/)    74537.50
# 8                    Depósitos/ Créditos Directos (%)      387.23
# 9   Gastos de Administración Anualizados/ Créditos...       47.99
# 10  Gastos de Operación Anualizados / Margen Finan...      384.65
# 11  Ingresos Financieros Anualizados / Activo Prod...       90.36
# 12                         Adeudos / Pasivo Total (%)       23.03
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)     5884.42
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      107.95
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        9.35
# 16  Utilidad Neta Anualizada sobre Activo Promedio...        9.73
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...       76.73
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       16.93
# 19                            Ratio de Capital Global       43.34
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2024-02-29
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       43.48
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       34.34
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       65.86
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       34.34
# 4   Créditos Atrasados con más de 90 días de atras...       25.35
# 5                Provisiones / Créditos Atrasados (%)      554.84
# 6            Créditos Directos / Empleados (Miles S/)     3389.93
# 7   Créditos Directos / Número de Oficinas (Miles S/)    74281.66
# 8                    Depósitos/ Créditos Directos (%)      385.21
# 9   Gastos de Administración Anualizados/ Créditos...       47.66
# 10  Gastos de Operación Anualizados / Margen Finan...      384.08
# 11  Ingresos Financieros Anualizados / Activo Prod...       90.09
# 12                         Adeudos / Pasivo Total (%)       21.80
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)     6261.43
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      108.82
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        2.18
# 16  Utilidad Neta Anualizada sobre Activo Promedio...       10.36
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...       82.24
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       16.65
# 19                            Ratio de Capital Global       44.01
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2024-03-31
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       43.34
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       34.22
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       65.19
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       34.22
# 4   Créditos Atrasados con más de 90 días de atras...       25.69
# 5                Provisiones / Créditos Atrasados (%)      564.43
# 6            Créditos Directos / Empleados (Miles S/)     3339.99
# 7   Créditos Directos / Número de Oficinas (Miles S/)    73562.27
# 8                    Depósitos/ Créditos Directos (%)      387.97
# 9   Gastos de Administración Anualizados/ Créditos...       47.41
# 10  Gastos de Operación Anualizados / Margen Finan...      381.11
# 11  Ingresos Financieros Anualizados / Activo Prod...       89.75
# 12                         Adeudos / Pasivo Total (%)       22.32
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)     6482.82
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      109.38
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        0.74
# 16  Utilidad Neta Anualizada sobre Activo Promedio...       11.47
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...       93.31
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       19.24
# 19                            Ratio de Capital Global       43.00
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2024-04-30
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       43.92
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       34.06
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       64.33
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       34.06
# 4   Créditos Atrasados con más de 90 días de atras...       26.97
# 5                Provisiones / Créditos Atrasados (%)      573.84
# 6            Créditos Directos / Empleados (Miles S/)     3441.11
# 7   Créditos Directos / Número de Oficinas (Miles S/)    73652.49
# 8                    Depósitos/ Créditos Directos (%)      386.63
# 9   Gastos de Administración Anualizados/ Créditos...       46.83
# 10  Gastos de Operación Anualizados / Margen Finan...      374.33
# 11  Ingresos Financieros Anualizados / Activo Prod...       89.50
# 12                         Adeudos / Pasivo Total (%)       22.56
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)     5887.85
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      104.84
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        2.54
# 16  Utilidad Neta Anualizada sobre Activo Promedio...       11.44
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...       96.77
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       19.07
# 19                            Ratio de Capital Global       43.09
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2024-05-31
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       44.71
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       34.83
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       62.59
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       34.83
# 4   Créditos Atrasados con más de 90 días de atras...       27.94
# 5                Provisiones / Créditos Atrasados (%)      543.89
# 6            Créditos Directos / Empleados (Miles S/)     3464.84
# 7   Créditos Directos / Número de Oficinas (Miles S/)    73074.07
# 8                    Depósitos/ Créditos Directos (%)      397.42
# 9   Gastos de Administración Anualizados/ Créditos...       46.71
# 10  Gastos de Operación Anualizados / Margen Finan...      372.08
# 11  Ingresos Financieros Anualizados / Activo Prod...       89.24
# 12                         Adeudos / Pasivo Total (%)       22.19
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)     4227.44
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      116.91
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        5.43
# 16  Utilidad Neta Anualizada sobre Activo Promedio...       11.84
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...      105.07
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       18.98
# 19                            Ratio de Capital Global       42.96
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2024-07-31
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       45.39
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       35.10
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       60.49
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       35.09
# 4   Créditos Atrasados con más de 90 días de atras...       29.61
# 5                Provisiones / Créditos Atrasados (%)      566.62
# 6            Créditos Directos / Empleados (Miles S/)     3509.86
# 7   Créditos Directos / Número de Oficinas (Miles S/)    72624.50
# 8                    Depósitos/ Créditos Directos (%)      387.64
# 9   Gastos de Administración Anualizados/ Créditos...       46.45
# 10  Gastos de Operación Anualizados / Margen Finan...      364.02
# 11  Ingresos Financieros Anualizados / Activo Prod...       89.05
# 12                         Adeudos / Pasivo Total (%)       20.34
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)    42320.41
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      107.10
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        3.36
# 16  Utilidad Neta Anualizada sobre Activo Promedio...       11.33
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...      108.63
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       17.72
# 19                            Ratio de Capital Global       42.87
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2024-08-31
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       46.67
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       36.37
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       59.33
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       36.36
# 4   Créditos Atrasados con más de 90 días de atras...       29.92
# 5                Provisiones / Créditos Atrasados (%)      573.44
# 6            Créditos Directos / Empleados (Miles S/)     3517.87
# 7   Créditos Directos / Número de Oficinas (Miles S/)    73124.44
# 8                    Depósitos/ Créditos Directos (%)      391.59
# 9   Gastos de Administración Anualizados/ Créditos...       46.52
# 10  Gastos de Operación Anualizados / Margen Finan...      367.30
# 11  Ingresos Financieros Anualizados / Activo Prod...       88.60
# 12                         Adeudos / Pasivo Total (%)       18.07
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)     4993.82
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      110.83
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        4.04
# 16  Utilidad Neta Anualizada sobre Activo Promedio...       11.71
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...      116.64
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       17.55
# 19                            Ratio de Capital Global       46.53
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2024-09-30
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       43.56
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       33.27
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       57.68
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       33.26
# 4   Créditos Atrasados con más de 90 días de atras...       28.40
# 5                Provisiones / Créditos Atrasados (%)      599.84
# 6            Créditos Directos / Empleados (Miles S/)     3503.93
# 7   Créditos Directos / Número de Oficinas (Miles S/)    73397.53
# 8                    Depósitos/ Créditos Directos (%)      387.61
# 9   Gastos de Administración Anualizados/ Créditos...       46.32
# 10  Gastos de Operación Anualizados / Margen Finan...      363.71
# 11  Ingresos Financieros Anualizados / Activo Prod...       88.68
# 12                         Adeudos / Pasivo Total (%)       17.11
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)     5109.57
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      109.07
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        4.03
# 16  Utilidad Neta Anualizada sobre Activo Promedio...       10.90
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...      112.95
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       17.37
# 19                            Ratio de Capital Global       47.98
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2024-10-31
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       42.86
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       32.68
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       53.08
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       32.68
# 4   Créditos Atrasados con más de 90 días de atras...       28.04
# 5                Provisiones / Créditos Atrasados (%)      627.66
# 6            Créditos Directos / Empleados (Miles S/)     3455.65
# 7   Créditos Directos / Número de Oficinas (Miles S/)    72987.54
# 8                    Depósitos/ Créditos Directos (%)      394.42
# 9   Gastos de Administración Anualizados/ Créditos...       46.40
# 10  Gastos de Operación Anualizados / Margen Finan...      365.61
# 11  Ingresos Financieros Anualizados / Activo Prod...       88.41
# 12                         Adeudos / Pasivo Total (%)       16.75
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)     4163.12
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      109.26
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        2.55
# 16  Utilidad Neta Anualizada sobre Activo Promedio...       11.38
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...      116.31
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       17.51
# 19                            Ratio de Capital Global       47.32
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2024-11-30
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       42.35
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       32.71
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       49.98
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       32.71
# 4   Créditos Atrasados con más de 90 días de atras...       26.59
# 5                Provisiones / Créditos Atrasados (%)      625.75
# 6            Créditos Directos / Empleados (Miles S/)     3572.57
# 7   Créditos Directos / Número de Oficinas (Miles S/)    74718.41
# 8                    Depósitos/ Créditos Directos (%)      394.89
# 9   Gastos de Administración Anualizados/ Créditos...       46.23
# 10  Gastos de Operación Anualizados / Margen Finan...      362.47
# 11  Ingresos Financieros Anualizados / Activo Prod...       88.41
# 12                         Adeudos / Pasivo Total (%)       17.23
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)     3062.46
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      123.77
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        4.74
# 16  Utilidad Neta Anualizada sobre Activo Promedio...       10.93
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...      113.28
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       17.74
# 19                            Ratio de Capital Global       46.28
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2024-12-31
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       38.89
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       29.76
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       49.43
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       29.75
# 4   Créditos Atrasados con más de 90 días de atras...       24.69
# 5                Provisiones / Créditos Atrasados (%)      601.29
# 6            Créditos Directos / Empleados (Miles S/)     3637.08
# 7   Créditos Directos / Número de Oficinas (Miles S/)    75461.12
# 8                    Depósitos/ Créditos Directos (%)      380.11
# 9   Gastos de Administración Anualizados/ Créditos...       46.51
# 10  Gastos de Operación Anualizados / Margen Finan...      362.17
# 11  Ingresos Financieros Anualizados / Activo Prod...       88.25
# 12                         Adeudos / Pasivo Total (%)       18.06
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)     5731.92
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      107.76
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        3.90
# 16  Utilidad Neta Anualizada sobre Activo Promedio...       10.57
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...      113.34
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       17.16
# 19                            Ratio de Capital Global       53.64
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2025-01-31
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       39.74
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       31.16
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       48.15
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       31.15
# 4   Créditos Atrasados con más de 90 días de atras...       25.73
# 5                Provisiones / Créditos Atrasados (%)      591.35
# 6            Créditos Directos / Empleados (Miles S/)     3750.98
# 7   Créditos Directos / Número de Oficinas (Miles S/)    74411.41
# 8                    Depósitos/ Créditos Directos (%)      385.91
# 9   Gastos de Administración Anualizados/ Créditos...       46.79
# 10  Gastos de Operación Anualizados / Margen Finan...      361.04
# 11  Ingresos Financieros Anualizados / Activo Prod...       88.11
# 12                         Adeudos / Pasivo Total (%)       18.90
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)     6227.79
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      116.06
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        2.31
# 16  Utilidad Neta Anualizada sobre Activo Promedio...        9.42
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...      102.74
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       17.83
# 19                            Ratio de Capital Global       51.77
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2025-02-28
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       40.31
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       31.80
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       45.14
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       31.80
# 4   Créditos Atrasados con más de 90 días de atras...       26.18
# 5                Provisiones / Créditos Atrasados (%)      588.22
# 6            Créditos Directos / Empleados (Miles S/)     3932.86
# 7   Créditos Directos / Número de Oficinas (Miles S/)    75200.13
# 8                    Depósitos/ Créditos Directos (%)      389.26
# 9   Gastos de Administración Anualizados/ Créditos...       46.69
# 10  Gastos de Operación Anualizados / Margen Finan...      356.59
# 11  Ingresos Financieros Anualizados / Activo Prod...       87.86
# 12                         Adeudos / Pasivo Total (%)       18.41
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)    16228.97
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      119.90
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        8.56
# 16  Utilidad Neta Anualizada sobre Activo Promedio...        8.36
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...       95.43
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       18.41
# 19                            Ratio de Capital Global       51.94
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2025-03-31
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       37.92
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       29.75
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       43.17
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       29.74
# 4   Créditos Atrasados con más de 90 días de atras...       24.26
# 5                Provisiones / Créditos Atrasados (%)      595.47
# 6            Créditos Directos / Empleados (Miles S/)     4058.72
# 7   Créditos Directos / Número de Oficinas (Miles S/)    76899.35
# 8                    Depósitos/ Créditos Directos (%)      382.59
# 9   Gastos de Administración Anualizados/ Créditos...       46.31
# 10  Gastos de Operación Anualizados / Margen Finan...      350.24
# 11  Ingresos Financieros Anualizados / Activo Prod...       87.86
# 12                         Adeudos / Pasivo Total (%)       15.49
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)    19471.40
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      119.11
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        7.99
# 16  Utilidad Neta Anualizada sobre Activo Promedio...        6.99
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...       84.30
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       18.64
# 19                            Ratio de Capital Global       52.22
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2025-04-30
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       37.17
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       29.33
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       78.63
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       29.34
# 4   Créditos Atrasados con más de 90 días de atras...       24.41
# 5                Provisiones / Créditos Atrasados (%)      586.28
# 6            Créditos Directos / Empleados (Miles S/)     3998.57
# 7   Créditos Directos / Número de Oficinas (Miles S/)    76484.43
# 8                    Depósitos/ Créditos Directos (%)      382.37
# 9   Gastos de Administración Anualizados/ Créditos...       46.28
# 10  Gastos de Operación Anualizados / Margen Finan...      345.94
# 11  Ingresos Financieros Anualizados / Activo Prod...       87.91
# 12                         Adeudos / Pasivo Total (%)       15.18
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)    16983.58
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      115.17
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        7.32
# 16  Utilidad Neta Anualizada sobre Activo Promedio...        5.85
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...       71.75
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       17.88
# 19                            Ratio de Capital Global       54.53
#
# ============================================================
# VALIDACIÓN PARA PERÍODO: 2025-07-31
# ============================================================
# Validaciones realizadas: 20
# Exitosas: 0
# Fallidas: 20
#
# ⚠️ Validaciones fallidas:
#                         categoria  \
# 0              CALIDAD DE ACTIVOS
# 1              CALIDAD DE ACTIVOS
# 2              CALIDAD DE ACTIVOS
# 3              CALIDAD DE ACTIVOS
# 4              CALIDAD DE ACTIVOS
# 5              CALIDAD DE ACTIVOS
# 6            EFICIENCIA Y GESTIÓN
# 7            EFICIENCIA Y GESTIÓN
# 8            EFICIENCIA Y GESTIÓN
# 9            EFICIENCIA Y GESTIÓN
# 10           EFICIENCIA Y GESTIÓN
# 11           EFICIENCIA Y GESTIÓN
# 12                       LIQUIDEZ
# 13                       LIQUIDEZ
# 14                       LIQUIDEZ
# 15  POSICIÓN EN MONEDA EXTRANJERA
# 16                   RENTABILIDAD
# 17                   RENTABILIDAD
# 18                      SOLVENCIA
# 19                      SOLVENCIA
#
#                                             indicador  diferencia
# 0      Cartera de Alto Riesgo / Créditos Directos (%)       37.43
# 1   Créditos Atrasados (criterio SBS)** / Créditos...       30.00
# 2   Créditos Atrasados ME (criterio SBS)** / Crédi...       81.18
# 3   Créditos Atrasados MN (criterio SBS)** / Crédi...       30.00
# 4   Créditos Atrasados con más de 90 días de atras...       24.51
# 5                Provisiones / Créditos Atrasados (%)      586.36
# 6            Créditos Directos / Empleados (Miles S/)     4182.68
# 7   Créditos Directos / Número de Oficinas (Miles S/)    79294.81
# 8                    Depósitos/ Créditos Directos (%)      390.10
# 9   Gastos de Administración Anualizados/ Créditos...       45.89
# 10  Gastos de Operación Anualizados / Margen Finan...      335.56
# 11  Ingresos Financieros Anualizados / Activo Prod...       87.21
# 12                         Adeudos / Pasivo Total (%)        9.44
# 13   Ratio de Liquidez en M.E. (%) (promedio del mes)    15450.74
# 14   Ratio de Liquidez en M.N. (%) (promedio del mes)      121.92
# 15  Posición Global en M.E. / Patrimonio Efectivo ...        5.87
# 16  Utilidad Neta Anualizada sobre Activo Promedio...        2.80
# 17  Utilidad Neta Anualizada sobre Patrimonio Prom...       38.29
# 18  Pasivo Total / Capital Social y Reservas ( Nº ...       17.43
# 19                            Ratio de Capital Global       55.04

# %% [markdown]
# ---
# ## 5. Exportar Dataset Consolidado

# %%
# Guardar dataset consolidado
if df_consolidado is not None:
    nombre_archivo_salida = 'indicadores_financieros_crac_consolidado.csv'
    df_consolidado.to_csv(nombre_archivo_salida, index=False)

    print(f"✓ Dataset consolidado exportado a: {nombre_archivo_salida}")
    print(f"  Registros totales: {len(df_consolidado):,}")
    print(f"  Tamaño del archivo: {os.path.getsize(nombre_archivo_salida) / 1024:.1f} KB")

    # Descargar archivo
    from google.colab import files
    files.download(nombre_archivo_salida)
# Out:
# ✓ Dataset consolidado exportado a: indicadores_financieros_crac_consolidado.csv
#   Registros totales: 1,920
#   Tamaño del archivo: 203.9 KB
